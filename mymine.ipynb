# %%
import os 
#pip install tweepy
import tweepy as tw
#import panda for dataframe
import pandas as pd 
  #conda update -n base -c defaults conda( to install tweepy package in the python all besic )
    #to access the tweet api create varible 4,
consumer_key= '**********************'
consumer_secret= '**************************'
access_token= '****************************'
acess_token_secret= '**************************'

 #to access the api create he authenticatons veriable 
auth = tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,acess_token_secret)
api =tw.API(auth )

#passing api to upadate status 
api.update_status("hiiiii.....")
#searching the home_timeline tweet (public tweet)
#public_tweet=api.home_timeline()
search_words= "#cod"
date_since="2021-1-1"

tweets= tw.Cursor(api.search,q=search_words,lang='en',sice=date_since).items(100)

# to know the tweet and its text 
for tweet in tweets:
    print("id:",tweet.id)
# konw when the tweet created date&time
for  tweet in public_tweet:
    print('tweets:',tweet.text)
    print("tweets at :",tweet.created_at)
    print(user_locs)
    
# to access the user locations ,screen name    
user_locs=[[tweet.user.screen_name,tweet.user.location,tweet.user.id,tweet.text,tweet.created_at]for tweet in tweets]
print(user_locs )

tweetsdata_frame=pd.DataFrame(data=user_locs,columns=['user_name',' Locations','   id  ','user_text','created_at'])
tweetsdata_frame

print( s=pd.DataFrame(data=user_locs,rows =('1','2,','3')))
# Out:
# [['RealDrCollision', 'Los Angeles, CA', 1272580109820624896, 'RT @DavidMayle8: LIVE!!!! Still trying to figure out this mouse and keyboard. https://t.co/yoV0RksJEE  #twitch #streaming #COD #battleroyal…', datetime.datetime(2021, 3, 6, 4, 13, 55)], ['BrickMode222', '', 1284599992296960000, 'RT @Gruntlifex03x: Next Tournament will be Private Lobby Solos winner take all! Drop a comment if interested so I can invite you to the Dis…', datetime.datetime(2021, 3, 6, 4, 13, 52)], ['wwwanpaus', 'Los Angeles, CA', 2834114661, 'RT @DavidMayle8: LIVE!!!! Still trying to figure out this mouse and keyboard. https://t.co/yoV0RksJEE  #twitch #streaming #COD #battleroyal…', datetime.datetime(2021, 3, 6, 4, 13, 34)], ['sme_rt', 'Manchester, UK', 1150729203563806720, 'RT @DavidMayle8: LIVE!!!! Still trying to figure out this mouse and keyboard. https://t.co/yoV0RksJEE  #twitch #streaming #COD #battleroyal…', datetime.datetime(2021, 3, 6, 4, 13, 22)], ['DavidMayle8', '', 1281609856185769987, 'LIVE!!!! Still trying to figure out this mouse and keyboard. https://t.co/yoV0RksJEE  #twitch #streaming #COD… https://t.co/y8aNMrTQwD', datetime.datetime(2021, 3, 6, 4, 12, 23)], ['EggoMyDiego', '', 328870071, "RT @_IlseArely_: https://t.co/nqIwRgDk4A\n\nCheck new video out on YT!\nDon't forget to subscribe and leave a 👍🏼\n#CoD #ModernWarfare #gamers #…", datetime.datetime(2021, 3, 6, 4, 8, 23)], ['ImLiveRT', '', 857019003826348032, 'RT @Angeezy520: https://t.co/9Qe4shgg2N I’m Live On Facebook Streaming #Warzone #SupportSmallStreamers #COD #ColdWar #ModernWarfare', datetime.datetime(2021, 3, 6, 4, 5, 16)], ['A_Joshi8', '', 325666230, 'Well...                                              @CallofDuty @InfinityWard #warzone #cod @FaZeClan @Temperrr… https://t.co/NRSKZeg1Td', datetime.datetime(2021, 3, 6, 4, 3, 55)], ['Angeezy520', 'Tucson, AZ', 251367815, 'https://t.co/9Qe4shgg2N I’m Live On Facebook Streaming #Warzone #SupportSmallStreamers #COD #ColdWar #ModernWarfare', datetime.datetime(2021, 3, 6, 4, 3, 44)], ['barrelfullgames', 'Las Vegas, NV', 1862288504, 'Glizzy Gladiators! https://t.co/53HQ0sK7Tj #warzone #cod #twitch #Warzoneclips', datetime.datetime(2021, 3, 6, 4, 3, 40)], ['ImBowTieMan', 'Memphis, TN', 3385560994, 'ENG/ PC/ Friday Fun time. #RMG #LivingLegends #COD https://t.co/A1XBVsiVtZ', datetime.datetime(2021, 3, 6, 4, 2, 10)], ['Hippie2trippy1', 'Arkansas ', 1274514111351730182, 'Killing it with the boys #Warzone #CoD #Xbox https://t.co/pLwJFygdCi', datetime.datetime(2021, 3, 6, 4, 1, 44)], ['Chuy18FMJ', '', 792556700096077824, 'WarZone Dubz! Come and Chat Love the Support Guys Thanks!!\nhttps://t.co/2KlNKXYHqR\n@streamboosts @twitchpromoters… https://t.co/nQm5gwH3So', datetime.datetime(2021, 3, 6, 4, 1, 4)], ['Roben_112', 'United States', 1251207700840579072, 'RT @BombsBarry: Starting soon! Come say #hi! #twitchtv #twitch #SmallStreamersConnect #SmallStreamerCommunity #Warzone #PathToAffiliate #ga…', datetime.datetime(2021, 3, 6, 4, 0, 52)], ['OfficialNoobie', 'OfficialNoobie@hotmail.com', 1713306884, 'RT @TTVJaYmZ: CSGO + WARZONE STREAM!\nCome and hang out😏🔥\n\n➡️https://t.co/HgRONVrpDr⬅️\n\nWeekly sub goal: 9/10\nWeekly Follow goal: 348/350\n\n🔥…', datetime.datetime(2021, 3, 6, 4, 0, 27)], ['EyeSeeU8', '', 2812702273, 'LIVE for the NIGHT STREAM!\n22 more guns for Dark Matter\U0001f90c🏻\n\n#CallofDuty #BlackOpsColdWar #CoD\n\n👉🏻https://t.co/bShqAyZ6xJ👈🏻', datetime.datetime(2021, 3, 6, 3, 58, 14)], ['zocker_hans', 'Deutschland', 873079632001499136, 'RT @DUKEofNEWCASTLE: FLIP OUT with me &amp; join the tightest #gaming family around! #Livestream NOW with #DeFam on some #CallofDuty #CoD #Warz…', datetime.datetime(2021, 3, 6, 3, 57, 46)], ['crackinnati513', '', 1361533409852538880, 'Straight massacre mode @CODColdWarNews @BlackOpsColdWar #BeastMode #BlackOpsColdWar #ColdWar #CallofDuty… https://t.co/6os2lMUHYr', datetime.datetime(2021, 3, 6, 3, 56, 54)], ['Renepo0h', '', 1343092966005608449, 'RT @Renepo0h: Going live on Twitch💗 Playing a variety  ...
#           user_name        Locations                 id    \
# 0   RealDrCollision  Los Angeles, CA  1272580109820624896
# 1      BrickMode222                   1284599992296960000
# 2         wwwanpaus  Los Angeles, CA           2834114661
# 3            sme_rt   Manchester, UK  1150729203563806720
# 4       DavidMayle8                   1281609856185769987
# ..              ...              ...                  ...
# 95        Naina8613         Pakistan   957883143989747712
# 96        Naina8613         Pakistan   957883143989747712
# 97        Naina8613         Pakistan   957883143989747712
# 98        Naina8613         Pakistan   957883143989747712
# 99   ThatsMrBanks2U          CT, 203            111324431
#
#                                             user_text          created_at
# 0   RT @DavidMayle8: LIVE!!!! Still trying to figu... 2021-03-06 04:13:55
# 1   RT @Gruntlifex03x: Next Tournament will be Pri... 2021-03-06 04:13:52
# 2   RT @DavidMayle8: LIVE!!!! Still trying to figu... 2021-03-06 04:13:34
# 3   RT @DavidMayle8: LIVE!!!! Still trying to figu... 2021-03-06 04:13:22
# 4   LIVE!!!! Still trying to figure out this mouse... 2021-03-06 04:12:23
# ..                                                ...                 ...
# 95  RT @Mutahir_Bhutto: inbox Thumbnail $5\n #sad ... 2021-03-06 03:16:28
# 96  RT @Mutahir_Bhutto: DM if u Buy\n#gamingcommun... 2021-03-06 03:16:24
# 97  RT @Mutahir_Bhutto: DM if u Buy\n#gamingcommun... 2021-03-06 03:16:19
# 98  RT @Mutahir_Bhutto: DM if u Buy\n#gamingcommun... 2021-03-06 03:15:55
# 99  Dads playin Warzone , tune in to the live stre... 2021-03-06 03:15:11
#
# [100 rows x 5 columns]

# %%
my_dict={"Roll_no":[1000,1001,1002,1003],'students_name' :["subbu ","naveen",'praveen','santhosh'],
           'age':[20,50,40,60],
            "marks":[1000,11,2222,222] }



import pandas as pd 

df= pd.DataFrame(my_dict,columns=["Roll_no","students_name","age","marks"])
#print(df)

print(df.head(2))
print(df.shape)
print(df["age"]==20)
# Out:
#    Roll_no students_name  age  marks
# 0     1000        subbu    20   1000
# 1     1001        naveen   50     11
# (4, 4)
# 0     True
# 1    False
# 2    False
# 3    False
# Name: age, dtype: bool

# %%
my_dict={"Roll_no":[1000,1001,1002,1003],'students_name' :["subbu ","naveen",'praveen','santhosh'],
           'age':[20,50,40,60],
            "marks":[1000,11,2222,222] }

record = {  
  
 'Name' : ['Ankit', 'Swapnil', 'Aishwarya',  
          'Priyanka', 'Shivangi', 'Shaurya' ], 
    
 'Age' : [22, 20, 21, 19, 18, 22],  
    
 'Stream' : ['Math', 'Commerce', 'Science',  
            'Math', 'Math', 'Science'],  
    
 'Percentage' : [90, 90, 96, 75, 70, 80] }  
    
# create a dataframe  
#dataframe = pd.DataFrame(record, 
                         #columns = ['Name','Age','Stream','Percentage'])
#print('', dataframe)
#print(dataframe['Name']=="Ankit")
print(marge(record,my_dict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-6c2f0c756534> in <module>
#      20 #print('', dataframe)
#      21 #print(dataframe['Name']=="Ankit")
# ---> 22 print(marge(record,my_dict))
#
# NameError: name 'marge' is not defined

# %%
# Out:
# 3.10.0
